# %%
import requests

url = "http://localhost:8000/invocations"
headers = {"Content-Type": "application/json"}

payload = {
    "dataframe_split": {
        "columns": [
            "name",
            "description",
            "neighbourhood_cleansed",
            "property_type",
            "room_type",
            "accommodates",
            "bathrooms",
            "bedrooms",
            "beds",
            "amenities"
        ],
        "data": [[
            "Triple Room With City View",
            "This tastefully decorated room has an elegant interior...",
            "Centrum-West",
            "Room in hotel",
            "Private room",
            4,
            1,
            1,
            3,
            "['High chair']"
        ]]
    }
}

response = requests.post(url, headers=headers, json=payload)
print("Response:", response.json())
# Out:
# Response: {'predictions': [{'0': 227.45229985364804}]}
